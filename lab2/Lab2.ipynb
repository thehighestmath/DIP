# %% [markdown]
# # ЦОИ, Лабораторная работа №2
# ## Крыжановский Кирилл, 8303
# ### Лабораторная работа по теме: Поиск особенностей в изображении

# %%
import math

import cv2
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure

# %%
def show_image(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    figure(figsize=(8, 8), dpi=80)
    plt.imshow(image)
    plt.show()

# %%
# DATA
path = r"C:\Users\therealyou\university\digital-imaging\lab2\example.png"

# %%
image = cv2.imread(path)
show_image(image)

# %%
output = image.copy()
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
circles = cv2.HoughCircles(gray, cv2.HOUGH_GRADIENT, 1.5, 100)
if circles is not None:
    circles = np.round(circles[0, :]).astype("int")
    for (x, y, r) in circles:
        cv2.circle(output, (x, y), r, (0, 255, 0), 4)
        cv2.rectangle(output, (x - 5, y - 5), (x + 5, y + 5), (0, 128, 255), -1)
    show_image(output)
